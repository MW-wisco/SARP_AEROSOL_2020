# %%
#importing packages
import pandas as pa
import matplotlib.pyplot as plt
import numpy as np
from tkinter import filedialog as fd
import matplotlib.pyplot as plt

# %%
#importing an example file (PM 2.5 Concentrations)
test_file = fd.askopenfilename()
with open(test_file) as FID:
    df = pa.read_csv(FID, delim_whitespace = False, dtype = 'str')

# %%
df
# Out:
#     State Code County Code Site Number Parameter Code POC  Latitude  \
# 0           36          81         124          88101   4  40.73614
# 1           36          81         124          88101   4  40.73614
# 2           36          81         124          88101   4  40.73614
# 3           36          81         124          88101   4  40.73614
# 4           36          81         124          88101   4  40.73614
# ..         ...         ...         ...            ...  ..       ...
# 143         36          81         124          88101   4  40.73614
# 144         36          81         124          88101   4  40.73614
# 145         36          81         124          88101   4  40.73614
# 146         36          81         124          88101   4  40.73614
# 147         36          81         124          88101   4  40.73614
#
#      Longitude  Datum            Parameter Name Duration Description  ... AQI  \
# 0    -73.82153  WGS84  PM2.5 - Local Conditions               1 HOUR  ...   .
# 1    -73.82153  WGS84  PM2.5 - Local Conditions               1 HOUR  ...   .
# 2    -73.82153  WGS84  PM2.5 - Local Conditions               1 HOUR  ...   .
# 3    -73.82153  WGS84  PM2.5 - Local Conditions               1 HOUR  ...   .
# 4    -73.82153  WGS84  PM2.5 - Local Conditions               1 HOUR  ...   .
# ..         ...    ...                       ...                  ...  ...  ..
# 143  -73.82153  WGS84  PM2.5 - Local Conditions               1 HOUR  ...   .
# 144  -73.82153  WGS84  PM2.5 - Local Conditions               1 HOUR  ...   .
# 145  -73.82153  WGS84  PM2.5 - Local Conditions               1 HOUR  ...   .
# 146  -73.82153  WGS84  PM2.5 - Local Conditions               1 HOUR  ...   .
# 147  -73.82153  WGS84  PM2.5 - Local Conditions               1 HOUR  ...   .
#
#     Daily Criteria Indicator Tribe Name State Name County Name City Name  \
# 0                          Y        NaN   New York      Queens  New York
# 1                          Y        NaN   New York      Queens  New York
# 2                          Y        NaN   New York      Queens  New York
# 3                          Y        NaN   New York      Queens  New York
# 4                          Y        NaN   New York      Queens  New York
# ..                       ...        ...        ...         ...       ...
# 143                        Y        NaN   New York      Queens  New York
# 144                        Y        NaN   New York      Queens  New York
# 145                        Y        NaN   New York      Queens  New York
# 146                        Y        NaN   New York      Queens  New York
# 147                        N        NaN   New York      Queens  New York
#
#       Local Site Name                                            Address  \
# 0    QUEENS COLLEGE 2  Queens College   65-30 Kissena Blvd  Parking L...
# 1    QUEENS COLLEGE 2  Queens College   65-30 Kissena Blvd  Parking L...
# 2    QUEENS COLLEGE 2  Queens College   65-30 Kissena Blvd  Parking L...
# 3    QUEENS COLLEGE 2  Queens College   65-30 Kissena Blvd  Parking L...
# 4    QUEENS COLLEGE 2  Queens College   65-30 Kissena Blvd  Parking L...
# ..                ...                                                ...
# 143  QUEENS COLLEGE 2  Queens College   65-30 Kissena Blvd  Parking L...
# 144  QUEENS COLLEGE 2  Queens College   65-30 Kissena Blvd  Parking L...
# 145  QUEENS COLLEGE 2  Queens College   65-30 Kissena Blvd  Parking L...
# 146  QUEENS COLLEGE 2  Queens College   65-30 Kissena Blvd  Parking L...
# 147  QUEENS COLLEGE 2  Queens College   65-30 Kissena Blvd  Parking L...
#
#                           MSA or CBSA Name    Data Source
# 0    New York-Newark-Jersey City, NY-NJ-PA  AQS Data Mart
# 1    New York-Newark-Jersey City, NY-NJ-PA  AQS Data Mart
# 2    New York-Newark-Jersey City, NY-NJ-PA  AQS Data Mart
# 3    New York-Newark-Jersey City, NY-NJ-PA  AQS Data Mart
# 4    New York-Newark-Jersey City, NY-NJ-PA  AQS Data Mart
# ..                                     ...            ...
# 143  New York-Newark-Jersey City, NY-NJ-PA  AQS Data Mart
# 144  New York-Newark-Jersey City, NY-NJ-PA  AQS Data Mart
# 145  New York-Newark-Jersey City, NY-NJ-PA  AQS Data Mart
# 146  New York-Newark-Jersey City, NY-NJ-PA  AQS Data Mart
# 147  New York-Newark-Jersey City, NY-NJ-PA  AQS Data Mart
#
# [148 rows x 34 columns]

# %%
#finding the important parameters
Mean = df['Arithmetic Mean']
Date = df['Date (Local)']
MaxV = df['First Maximum Value']

# %%
# setting the max value and mean to a float value
MaxV = MaxV.astype('float16')
Mean = Mean.astype('float16')

# %%
# making the graph a bit nicer
import seaborn
seaborn.set()

# %%
# make the date into datetime objects
Date_format = pa.to_datetime(Date, format = '%Y-%m-%d')
Date_format
# Out:
# 0     2020-01-01
# 1     2020-01-02
# 2     2020-01-03
# 3     2020-01-04
# 4     2020-01-05
#          ...
# 143   2020-05-23
# 144   2020-05-24
# 145   2020-05-25
# 146   2020-05-26
# 147   2020-05-27
# Name: Date (Local), Length: 148, dtype: datetime64[ns]

# %%
#plot the graph
fig, ax = plt.subplots(figsize=(15,10))
ax.plot(Date_format, Mean, color = 'red' )
ax.set_title('PM2.5 Concentrations for Site: Queens College')
ax.set_xlabel('Date')
ax.set_ylabel('Mean PM2.5')
fig.savefig('PM2.5(QC).png')
#what's causing these trends? (try smoothing out the data, look at past years(seasonal trend?))

# %%
#importing an example file (NO2 Concentrations)
test_file = fd.askopenfilename()
with open(test_file) as FID:
    df_2 = pa.read_csv(FID, delim_whitespace = False, dtype = 'str')

# %%
df_2
# Out:
#     State Code County Code Site Number Parameter Code POC  Latitude  \
# 0           36          81         124          42602   1  40.73614
# 1           36          81         124          42602   1  40.73614
# 2           36          81         124          42602   1  40.73614
# 3           36          81         124          42602   1  40.73614
# 4           36          81         124          42602   1  40.73614
# ..         ...         ...         ...            ...  ..       ...
# 147         36          81         124          42602   1  40.73614
# 148         36          81         124          42602   1  40.73614
# 149         36          81         124          42602   1  40.73614
# 150         36          81         124          42602   1  40.73614
# 151         36          81         124          42602   1  40.73614
#
#      Longitude  Datum          Parameter Name Duration Description  ... AQI  \
# 0    -73.82153  WGS84  Nitrogen dioxide (NO2)               1 HOUR  ...  12
# 1    -73.82153  WGS84  Nitrogen dioxide (NO2)               1 HOUR  ...  39
# 2    -73.82153  WGS84  Nitrogen dioxide (NO2)               1 HOUR  ...  33
# 3    -73.82153  WGS84  Nitrogen dioxide (NO2)               1 HOUR  ...  28
# 4    -73.82153  WGS84  Nitrogen dioxide (NO2)               1 HOUR  ...  12
# ..         ...    ...                     ...                  ...  ...  ..
# 147  -73.82153  WGS84  Nitrogen dioxide (NO2)               1 HOUR  ...  13
# 148  -73.82153  WGS84  Nitrogen dioxide (NO2)               1 HOUR  ...  16
# 149  -73.82153  WGS84  Nitrogen dioxide (NO2)               1 HOUR  ...  15
# 150  -73.82153  WGS84  Nitrogen dioxide (NO2)               1 HOUR  ...  19
# 151  -73.82153  WGS84  Nitrogen dioxide (NO2)               1 HOUR  ...   4
#
#     Daily Criteria Indicator Tribe Name State Name County Name City Name  \
# 0                          Y        NaN   New York      Queens  New York
# 1                          Y        NaN   New York      Queens  New York
# 2                          Y        NaN   New York      Queens  New York
# 3                          Y        NaN   New York      Queens  New York
# 4                          Y        NaN   New York      Queens  New York
# ..                       ...        ...        ...         ...       ...
# 147                        Y        NaN   New York      Queens  New York
# 148                        Y        NaN   New York      Queens  New York
# 149                        Y        NaN   New York      Queens  New York
# 150                        Y        NaN   New York      Queens  New York
# 151                        Y        NaN   New York      Queens  New York
#
#       Local Site Name                                            Address  \
# 0    QUEENS COLLEGE 2  Queens College   65-30 Kissena Blvd  Parking L...
# 1    QUEENS COLLEGE 2  Queens College   65-30 Kissena Blvd  Parking L...
# 2    QUEENS COLLEGE 2  Queens College   65-30 Kissena Blvd  Parking L...
# 3    QUEENS COLLEGE 2  Queens College   65-30 Kissena Blvd  Parking L...
# 4    QUEENS COLLEGE 2  Queens College   65-30 Kissena Blvd  Parking L...
# ..                ...                                                ...
# 147  QUEENS COLLEGE 2  Queens College   65-30 Kissena Blvd  Parking L...
# 148  QUEENS COLLEGE 2  Queens College   65-30 Kissena Blvd  Parking L...
# 149  QUEENS COLLEGE 2  Queens College   65-30 Kissena Blvd  Parking L...
# 150  QUEENS COLLEGE 2  Queens College   65-30 Kissena Blvd  Parking L...
# 151  QUEENS COLLEGE 2  Queens College   65-30 Kissena Blvd  Parking L...
#
#                           MSA or CBSA Name    Data Source
# 0    New York-Newark-Jersey City, NY-NJ-PA  AQS Data Mart
# 1    New York-Newark-Jersey City, NY-NJ-PA  AQS Data Mart
# 2    New York-Newark-Jersey City, NY-NJ-PA  AQS Data Mart
# 3    New York-Newark-Jersey City, NY-NJ-PA  AQS Data Mart
# 4    New York-Newark-Jersey City, NY-NJ-PA  AQS Data Mart
# ..                                     ...            ...
# 147  New York-Newark-Jersey City, NY-NJ-PA  AQS Data Mart
# 148  New York-Newark-Jersey City, NY-NJ-PA  AQS Data Mart
# 149  New York-Newark-Jersey City, NY-NJ-PA  AQS Data Mart
# 150  New York-Newark-Jersey City, NY-NJ-PA  AQS Data Mart
# 151  New York-Newark-Jersey City, NY-NJ-PA  AQS Data Mart
#
# [152 rows x 34 columns]

# %%
#finding the important parameters
Mean_1 = df_2['Arithmetic Mean']
Date_1 = df_2['Date (Local)']
MaxV_1 = df_2['First Maximum Value']

# %%
#changing to float value
Mean_1 = Mean_1.astype('float16')
MaxV_1 = MaxV_1.astype('float16')

# %%
Date_NO2 = pa.to_datetime(Date_1, format = "%Y-%m-%d")
Date_NO2
# Out:
# 0     2020-01-01
# 1     2020-01-02
# 2     2020-01-03
# 3     2020-01-04
# 4     2020-01-05
#          ...
# 147   2020-05-27
# 148   2020-05-28
# 149   2020-05-29
# 150   2020-05-30
# 151   2020-05-31
# Name: Date (Local), Length: 152, dtype: datetime64[ns]

# %%
#plot the graph
fig, ax = plt.subplots(figsize=(15,10))
ax.plot(Date_NO2, Mean_1, color = 'blue' )
ax.set_title('NO2 Concentrations for Site: Queens College')
ax.set_xlabel('Date')
ax.set_ylabel('Mean NO2')
fig.savefig('NO2(QC).png')

# %%
#importing an example file (Ozone Concentrations)
test_file = fd.askopenfilename()
with open(test_file) as FID:
    df_3 = pa.read_csv(FID, delim_whitespace = False, dtype = 'str')

# %%
df_3
# Out:
#     State Code County Code Site Number Parameter Code POC  Latitude  \
# 0           36          81         124          44201   1  40.73614
# 1           36          81         124          44201   1  40.73614
# 2           36          81         124          44201   1  40.73614
# 3           36          81         124          44201   1  40.73614
# 4           36          81         124          44201   1  40.73614
# ..         ...         ...         ...            ...  ..       ...
# 147         36          81         124          44201   1  40.73614
# 148         36          81         124          44201   1  40.73614
# 149         36          81         124          44201   1  40.73614
# 150         36          81         124          44201   1  40.73614
# 151         36          81         124          44201   1  40.73614
#
#      Longitude  Datum Parameter Name     Duration Description  ... AQI  \
# 0    -73.82153  WGS84          Ozone  8-HR RUN AVG BEGIN HOUR  ...  23
# 1    -73.82153  WGS84          Ozone  8-HR RUN AVG BEGIN HOUR  ...  16
# 2    -73.82153  WGS84          Ozone  8-HR RUN AVG BEGIN HOUR  ...   3
# 3    -73.82153  WGS84          Ozone  8-HR RUN AVG BEGIN HOUR  ...  25
# 4    -73.82153  WGS84          Ozone  8-HR RUN AVG BEGIN HOUR  ...  30
# ..         ...    ...            ...                      ...  ...  ..
# 147  -73.82153  WGS84          Ozone  8-HR RUN AVG BEGIN HOUR  ...  25
# 148  -73.82153  WGS84          Ozone  8-HR RUN AVG BEGIN HOUR  ...  19
# 149  -73.82153  WGS84          Ozone  8-HR RUN AVG BEGIN HOUR  ...  20
# 150  -73.82153  WGS84          Ozone  8-HR RUN AVG BEGIN HOUR  ...  44
# 151  -73.82153  WGS84          Ozone  8-HR RUN AVG BEGIN HOUR  ...  33
#
#     Daily Criteria Indicator Tribe Name State Name County Name City Name  \
# 0                          Y        NaN   New York      Queens  New York
# 1                          Y        NaN   New York      Queens  New York
# 2                          Y        NaN   New York      Queens  New York
# 3                          Y        NaN   New York      Queens  New York
# 4                          Y        NaN   New York      Queens  New York
# ..                       ...        ...        ...         ...       ...
# 147                        Y        NaN   New York      Queens  New York
# 148                        Y        NaN   New York      Queens  New York
# 149                        Y        NaN   New York      Queens  New York
# 150                        Y        NaN   New York      Queens  New York
# 151                        N        NaN   New York      Queens  New York
#
#       Local Site Name                                            Address  \
# 0    QUEENS COLLEGE 2  Queens College   65-30 Kissena Blvd  Parking L...
# 1    QUEENS COLLEGE 2  Queens College   65-30 Kissena Blvd  Parking L...
# 2    QUEENS COLLEGE 2  Queens College   65-30 Kissena Blvd  Parking L...
# 3    QUEENS COLLEGE 2  Queens College   65-30 Kissena Blvd  Parking L...
# 4    QUEENS COLLEGE 2  Queens College   65-30 Kissena Blvd  Parking L...
# ..                ...                                                ...
# 147  QUEENS COLLEGE 2  Queens College   65-30 Kissena Blvd  Parking L...
# 148  QUEENS COLLEGE 2  Queens College   65-30 Kissena Blvd  Parking L...
# 149  QUEENS COLLEGE 2  Queens College   65-30 Kissena Blvd  Parking L...
# 150  QUEENS COLLEGE 2  Queens College   65-30 Kissena Blvd  Parking L...
# 151  QUEENS COLLEGE 2  Queens College   65-30 Kissena Blvd  Parking L...
#
#                           MSA or CBSA Name    Data Source
# 0    New York-Newark-Jersey City, NY-NJ-PA  AQS Data Mart
# 1    New York-Newark-Jersey City, NY-NJ-PA  AQS Data Mart
# 2    New York-Newark-Jersey City, NY-NJ-PA  AQS Data Mart
# 3    New York-Newark-Jersey City, NY-NJ-PA  AQS Data Mart
# 4    New York-Newark-Jersey City, NY-NJ-PA  AQS Data Mart
# ..                                     ...            ...
# 147  New York-Newark-Jersey City, NY-NJ-PA  AQS Data Mart
# 148  New York-Newark-Jersey City, NY-NJ-PA  AQS Data Mart
# 149  New York-Newark-Jersey City, NY-NJ-PA  AQS Data Mart
# 150  New York-Newark-Jersey City, NY-NJ-PA  AQS Data Mart
# 151  New York-Newark-Jersey City, NY-NJ-PA  AQS Data Mart
#
# [152 rows x 34 columns]

# %%
#important parameters
Mean_2 = df_3['Arithmetic Mean']
Date_2 = df_3['Date (Local)']
MaxV_2 = df_3['First Maximum Value']

# %%
#changing to float value
Mean_2 = Mean_2.astype('float16')
MaxV_2 = MaxV_2.astype('float16')

# %%
#changing str to datetime objects
Date_O = pa.to_datetime(Date_2, format = '%Y-%m-%d')
Date_O
# Out:
# 0     2020-01-01
# 1     2020-01-02
# 2     2020-01-03
# 3     2020-01-04
# 4     2020-01-05
#          ...
# 147   2020-05-27
# 148   2020-05-28
# 149   2020-05-29
# 150   2020-05-30
# 151   2020-05-31
# Name: Date (Local), Length: 152, dtype: datetime64[ns]

# %%
#creating a graph for ozone concentrations for Queens College
fig, ax = plt.subplots(figsize=(15,10))
ax.plot(Date_O, Mean_2, color = 'green' )
ax.set_title('Ozone Concentrations for Site: Queens College')
ax.set_xlabel('Date')
ax.set_ylabel('Mean Ozone(O3)')
fig.savefig('O(QC).png')

# %%
#importing an example file (SO2 Concentrations)
test_file = fd.askopenfilename()
with open(test_file) as FID:
    df_4 = pa.read_csv(FID, delim_whitespace = False, dtype = 'str')

# %%
df_4
# Out:
#     State Code County Code Site Number Parameter Code POC  Latitude  \
# 0           36          81         124          42401   2  40.73614
# 1           36          81         124          42401   2  40.73614
# 2           36          81         124          42401   2  40.73614
# 3           36          81         124          42401   2  40.73614
# 4           36          81         124          42401   2  40.73614
# ..         ...         ...         ...            ...  ..       ...
# 147         36          81         124          42401   2  40.73614
# 148         36          81         124          42401   2  40.73614
# 149         36          81         124          42401   2  40.73614
# 150         36          81         124          42401   2  40.73614
# 151         36          81         124          42401   2  40.73614
#
#      Longitude  Datum  Parameter Name Duration Description  ... AQI  \
# 0    -73.82153  WGS84  Sulfur dioxide               1 HOUR  ...   0
# 1    -73.82153  WGS84  Sulfur dioxide               1 HOUR  ...   9
# 2    -73.82153  WGS84  Sulfur dioxide               1 HOUR  ...   1
# 3    -73.82153  WGS84  Sulfur dioxide               1 HOUR  ...   0
# 4    -73.82153  WGS84  Sulfur dioxide               1 HOUR  ...   0
# ..         ...    ...             ...                  ...  ...  ..
# 147  -73.82153  WGS84  Sulfur dioxide               1 HOUR  ...   0
# 148  -73.82153  WGS84  Sulfur dioxide               1 HOUR  ...   0
# 149  -73.82153  WGS84  Sulfur dioxide               1 HOUR  ...   0
# 150  -73.82153  WGS84  Sulfur dioxide               1 HOUR  ...   0
# 151  -73.82153  WGS84  Sulfur dioxide               1 HOUR  ...   0
#
#     Daily Criteria Indicator Tribe Name State Name County Name City Name  \
# 0                          Y        NaN   New York      Queens  New York
# 1                          Y        NaN   New York      Queens  New York
# 2                          Y        NaN   New York      Queens  New York
# 3                          Y        NaN   New York      Queens  New York
# 4                          Y        NaN   New York      Queens  New York
# ..                       ...        ...        ...         ...       ...
# 147                        Y        NaN   New York      Queens  New York
# 148                        Y        NaN   New York      Queens  New York
# 149                        Y        NaN   New York      Queens  New York
# 150                        Y        NaN   New York      Queens  New York
# 151                        Y        NaN   New York      Queens  New York
#
#       Local Site Name                                            Address  \
# 0    QUEENS COLLEGE 2  Queens College   65-30 Kissena Blvd  Parking L...
# 1    QUEENS COLLEGE 2  Queens College   65-30 Kissena Blvd  Parking L...
# 2    QUEENS COLLEGE 2  Queens College   65-30 Kissena Blvd  Parking L...
# 3    QUEENS COLLEGE 2  Queens College   65-30 Kissena Blvd  Parking L...
# 4    QUEENS COLLEGE 2  Queens College   65-30 Kissena Blvd  Parking L...
# ..                ...                                                ...
# 147  QUEENS COLLEGE 2  Queens College   65-30 Kissena Blvd  Parking L...
# 148  QUEENS COLLEGE 2  Queens College   65-30 Kissena Blvd  Parking L...
# 149  QUEENS COLLEGE 2  Queens College   65-30 Kissena Blvd  Parking L...
# 150  QUEENS COLLEGE 2  Queens College   65-30 Kissena Blvd  Parking L...
# 151  QUEENS COLLEGE 2  Queens College   65-30 Kissena Blvd  Parking L...
#
#                           MSA or CBSA Name    Data Source
# 0    New York-Newark-Jersey City, NY-NJ-PA  AQS Data Mart
# 1    New York-Newark-Jersey City, NY-NJ-PA  AQS Data Mart
# 2    New York-Newark-Jersey City, NY-NJ-PA  AQS Data Mart
# 3    New York-Newark-Jersey City, NY-NJ-PA  AQS Data Mart
# 4    New York-Newark-Jersey City, NY-NJ-PA  AQS Data Mart
# ..                                     ...            ...
# 147  New York-Newark-Jersey City, NY-NJ-PA  AQS Data Mart
# 148  New York-Newark-Jersey City, NY-NJ-PA  AQS Data Mart
# 149  New York-Newark-Jersey City, NY-NJ-PA  AQS Data Mart
# 150  New York-Newark-Jersey City, NY-NJ-PA  AQS Data Mart
# 151  New York-Newark-Jersey City, NY-NJ-PA  AQS Data Mart
#
# [152 rows x 34 columns]

# %%
#important parameters
Mean_3 = df_4['Arithmetic Mean']
Date_3 = df_4['Date (Local)']
MaxV_3 = df_4['First Maximum Value']

# %%
#changing to float value
Mean_3 = Mean_3.astype('float16')
MaxV_3 = MaxV_3.astype('float16')

# %%
#changing to datetime objects
Date_SO2 = pa.to_datetime(Date_3, format ='%Y-%m-%d')
Date_SO2
# Out:
# 0     2020-01-01
# 1     2020-01-02
# 2     2020-01-03
# 3     2020-01-04
# 4     2020-01-05
#          ...
# 147   2020-05-27
# 148   2020-05-28
# 149   2020-05-29
# 150   2020-05-30
# 151   2020-05-31
# Name: Date (Local), Length: 152, dtype: datetime64[ns]

# %%
#creating a graph for ozone concentrations for Queens College
fig, ax = plt.subplots(figsize=(15,10))
ax.plot(Date_SO2, Mean_3, color = 'black' )
ax.set_title('SO2 Concentrations for Site: Queens College')
ax.set_xlabel('Date')
ax.set_ylabel('Mean SO2')
fig.savefig('SO2(QC).png')
